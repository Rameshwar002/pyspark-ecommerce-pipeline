# %%
import pandas as pd
import matplotlib.pyplot as plt
import os

# %%
df=pd.read_csv("D:\\GitAction\\pyspark-ecommerce-pipeline\\data\\raw\\customers_large.csv")
print(df.columns.tolist())
df.columns = df.columns.str.strip()   # removes leading/trailing spaces

        # 📊 Pie chart: Sales distribution by product
product_sales = df.groupby("product_id")["amount"].sum()
product_sales.plot(kind="pie", autopct='%1.1f%%', figsize=(6, 6), legend=False)
plt.title("Sales Distribution by Product")
# Out:
# ['customer_id', 'name', 'email', 'location']
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[11], line 6
#       3 df.columns = df.columns.str.strip()   # removes leading/trailing spaces
#       5         # 📊 Pie chart: Sales distribution by product
# ----> 6 product_sales = df.groupby("product_id")["amount"].sum()
#       7 product_sales.plot(kind="pie", autopct='%1.1f%%', figsize=(6, 6), legend=False)
#       8 plt.title("Sales Distribution by Product")
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\frame.py:9190, in DataFrame.groupby(self, by, axis, level, as_index, sort, group_keys, observed, dropna)
#    9187 if level is None and by is None:
#    9188     raise TypeError("You have to supply one of 'by' and 'level'")
# -> 9190 return DataFrameGroupBy(
# ...

# %%
df=pd.read_csv("d:\\GitAction\\pyspark-ecommerce-pipeline\\output\\transformed\enriched_data.csv")
print(df.columns.tolist())
df.columns = df.columns.str.strip()   # removes leading/trailing spaces

        # 📊 Pie chart: Sales distribution by product
product_sales = df.groupby("customer_id")["amount"].sum()

product_sales.plot(kind="pie", autopct='%1.1f%%', figsize=(6, 6), legend=False)
plt.title("Sales Distribution by Product")
# Out:
# ['product_id', 'customer_id', 'order_id', 'order_date', 'amount', 'name', 'email', 'location', 'category', 'price']
# Text(0.5, 1.0, 'Sales Distribution by Product')

# %%
df=pd.read_csv("D:\\GitAction\\pyspark-ecommerce-pipeline\\data\\raw\\customers_large.csv")
print("Columns in DataFrame:", df.columns.tolist())
print(df.head())
# Out:
# Columns in DataFrame: ['customer_id', 'name', 'email', 'location']
#    customer_id            name                     email   location
# 0            1     Jose Cooper    martinezlisa@yahoo.com       Pune
# 1            2    Julia George      yaguilar@hotmail.com    Chennai
# 2            3  Tiffany Melton  keithbutler@mathews.info    Kolkata
# 3            4    Matthew Hall        lisa35@wheeler.com       Pune
# 4            5     Paul Bright      lorimontoya@wong.org  Hyderabad

# %%
df=pd.read_csv("d:\\GitAction\\pyspark-ecommerce-pipeline\\output\\transformed\enriched_data.csv")
print(df.columns.tolist())
df.columns = df.columns.str.strip()   # removes leading/trailing spaces


# Group by product_id and sum amounts
product_sales = df.groupby("product_id")["amount"].sum().sort_values(ascending=False)

# Plot bar chart
plt.figure(figsize=(10,6))
product_sales.plot(kind="bar", color="skyblue", edgecolor="black")

plt.title("Sales Amount by Product", fontsize=14)
plt.xlabel("Product ID", fontsize=12)
plt.ylabel("Total Sales Amount", fontsize=12)
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()
# Out:
# ['product_id', 'customer_id', 'order_id', 'order_date', 'amount', 'name', 'email', 'location', 'category', 'price']

# %%
import matplotlib.pyplot as plt

# Take top 10 products
top_products = product_sales.sort_values(ascending=False).head(10)

plt.figure(figsize=(10, 6))
top_products.plot(kind="bar", color="skyblue", edgecolor="black")

plt.title("Top 10 Products by Sales Amount")
plt.xlabel("Product ID")
plt.ylabel("Total Sales Amount")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
top_products = product_sales.sort_values(ascending=False).head(20)

plt.figure(figsize=(10, 8))
top_products.plot(kind="barh", color="lightgreen", edgecolor="black")

plt.title("Top 20 Products by Sales Amount")
plt.xlabel("Total Sales Amount")
plt.ylabel("Product ID")
plt.tight_layout()
plt.show()
